# %%
import pandas as pd
import numpy as np
import seaborn as sns

df = pd.read_csv('Allstatesinsurvey/all_deaths.csv', encoding='cp1252')

# %%
# cleaning 

df_temp = df
df_temp['gender'] = df_temp['gender'].str.lower()

df_temp['cause_short'] = df_temp['cause_short'].str.lower()

df_temp['what_info_from_media'] = df_temp['what_info_from_media'].str.lower()

df_temp['cause_detail'] = df_temp['cause_detail'].str.lower()

df_temp['num_media_descriptors'] = 0

df_temp['num_media_descriptors'] = df_temp['what_info_from_media'].str.split(",").str.len()
# Out:
#      id state     county                              jail  year  \
# 4   1.0    AL    Baldwin       Baldwin County Corr. Center  2018
# 8   2.0    AL    Calhoun               Calhoun County Jail  2013
# 9   2.0    AL    Calhoun               Calhoun County Jail  2015
# 10  2.0    AL    Calhoun               Calhoun County Jail  2018
# 11  3.0    AL     Etowah    Etowah County Detention Center  2011
# 12  3.0    AL     Etowah    Etowah County Detention Center  2011
# 13  3.0    AL     Etowah    Etowah County Detention Center  2013
# 14  3.0    AL     Etowah    Etowah County Detention Center  2016
# 15  3.0    AL     Etowah    Etowah County Detention Center  2016
# 16  3.0    AL     Etowah    Etowah County Detention Center  2017
# 17  4.0    AL    Houston               Houston County Jail  2008
# 18  4.0    AL    Houston               Houston County Jail  2012
# 19  4.0    AL    Houston               Houston County Jail  2015
# 20  4.0    AL    Houston               Houston County Jail  2016
# 21  4.0    AL    Houston               Houston County Jail  2016
# 22  4.0    AL    Houston               Houston County Jail  2019
# 23  5.0    AL  Jefferson  Jefferson County Birmingham Jail  2013
# 24  5.0    AL  Jefferson  Jefferson County Birmingham Jail  2014
# 25  5.0    AL  Jefferson  Jefferson County Birmingham Jail  2014
# 26  5.0    AL  Jefferson  Jefferson County Birmingham Jail  2018
#
#    date_of_death full_name last_name first_name mid_name  ...  \
# 4            NaN       NaN       NaN        NaN      NaN  ...
# 8      7/19/2013       NaN       NaN        NaN      NaN  ...
# 9      1/17/2015       NaN    Hopper    William  Jeffrey  ...
# 10     7/14/2018       NaN    Taylor     Brett    Verdun  ...
# 11           NaN       NaN       NaN        NaN      NaN  ...
# 12           NaN       NaN       NaN        NaN      NaN  ...
# 13           NaN       NaN       NaN        NaN      NaN  ...
# 14           NaN       NaN       NaN        NaN      NaN  ...
# 15           NaN       NaN       NaN        NaN      NaN  ...
# 16           NaN       NaN       NaN        NaN      NaN  ...
# 17           NaN       NaN    Howell     Ronald      NaN  ...
# 18    12/10/2012       NaN     Floyd     Donald      Ray  ...
# 19    10/31/2015       NaN    Dozier     Martez   Rashad  ...
# 20           NaN       NaN    Townes  Archibald      NaN  ...
# 21           NaN       NaN     Tatum      Sarah      NaN  ...
# 22     8/31/2019       NaN    Mathis   Carlton     James  ...
# 23           NaN       NaN       NaN        NaN      NaN  ...
# 24           NaN       NaN       NaN        NaN      NaN  ...
# 25           NaN       NaN       NaN        NaN      NaN  ...
# 26           NaN       NaN       NaN        NaN      NaN  ...
#
#                                          cause_detail        dob yob   age  \
# 4                              acute bronchopneumonia        NaN NaN   NaN
# 8                                        heart attack        NaN NaN  59.0
# 9                                             hanging        NaN NaN  49.0
# 10                           methamphetamine toxicity  7/26/1983 NaN  34.0
# 11                                       heart attack        NaN NaN   NaN
# 12                                       heart attack        NaN NaN   NaN
# 13                                       heart attack        NaN NaN   NaN
# 14                        metastatic breast carcinoma        NaN NaN   NaN
# 15                        gastrointestinal hemorrhage        NaN NaN   NaN
# 16                           methamphetamine toxicity        NaN NaN   NaN
# 17                                    medical related        NaN NaN   NaN
# 18  medical related, (heart attack after surgery/j...  1/16/1959 NaN  53.0
# 19                                            hanging        NaN NaN  25.0
# 20                                    medical related        NaN NaN  52.0
# 21                                    medical related        NaN NaN   NaN
# 22                                            hanging        NaN NaN  30.0
# 23                           died from medical issues        NaN NaN   NaN
# 24                           died from medical issues        NaN NaN   NaN
# 25                           died from medical issues        NaN NaN   NaN
# 26              natural causes/pre-existing condition        NaN NaN   NaN
#
#    race  race_detail  gender custody_status  \
# 4   NaN          NaN     NaN            NaN
# 8   NaN          NaN     NaN            NaN
# 9     W          NaN       m              C
# 10    W          NaN       m            NaN
# 11  NaN          NaN     NaN            NaN
# 12  NaN          NaN     NaN            NaN
# 13  NaN          NaN     NaN            NaN
# 14  NaN          NaN     NaN            NaN
# 15  NaN          NaN     NaN            NaN
# 16  NaN          NaN     NaN            NaN
# 17  NaN          NaN       m            NaN
# 18    W          NaN       m              U
# 19  NaN          NaN       m              U
# 20    B          NaN       m              U
# 21  NaN          NaN       f            NaN
# 22    W          NaN       m              U
# 23  NaN          NaN     NaN            NaN
# 24  NaN          NaN     NaN            NaN
# 25  NaN          NaN     NaN            NaN
# 26  NaN          NaN     NaN            NaN
#
#                                  what_info_from_media num_media_descriptors
# 4                                                 NaN                   NaN
# 8                                  date of death, age                   2.0
# 9                 name, age, race, date of death, cod                   5.0
# 10                     name, dob, date of death, race                   4.0
# 11                                                NaN                   NaN
# 12                                                NaN                   NaN
# 13                                                NaN                   NaN
# 14                                                NaN                   NaN
# 15                                                NaN                   NaN
# 16                                                NaN                   NaN
# 17                                                NaN                   NaN
# 18  date of death, age, custody status, date of ar...                   4.0
# 19                 date of death, age, custody status                   3.0
# 20                       age, race, conviction status                   3.0
# 21                                                NaN                   NaN
# 22        date of death, age, race, conviction status                   4.0
# 23                                                NaN                   NaN
# 24                                                NaN                   NaN
# 25                                                NaN                   NaN
# 26                                                NaN                   NaN
#
# [20 rows x 23 columns]

# %%
# save
