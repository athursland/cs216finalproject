# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
jails = pd.read_csv("AllStatesinSurvey/all_jails.csv", encoding='cp1252')

# %%
jails.shape
# Out:
# (523, 116)

# %%
jails.head()
# Out:
#    id    fips statecode    state state_notes     county  \
# 0   1  1003.0        AL  Alabama         NaN    Baldwin
# 1   2  1015.0        AL  Alabama         NaN    Calhoun
# 2   3  1055.0        AL  Alabama         NaN     Etowah
# 3   4  1069.0        AL  Alabama         NaN    Houston
# 4   5  1073.0        AL  Alabama         NaN  Jefferson
#
#                                jail  \
# 0       Baldwin County Corr. Center
# 1               Calhoun County Jail
# 2    Etowah County Detention Center
# 3               Houston County Jail
# 4  Jefferson County Birmingham Jail
#
#                                           jail_notes  d2008  d2009  ...  \
# 0                                                NaN    0.0    0.0  ...
# 1                                                NaN    0.0    1.0  ...
# 2                                                NaN    0.0    0.0  ...
# 3                                                NaN    1.0    0.0  ...
# 4  ADP for 2008 was based on data provided by the...    NaN    NaN  ...
#
#                                  med2010  \
# 0                                 public
# 1                                 public
# 2  Doctors' Care Family Medical Services
# 3                                 public
# 4                       Health Assurance
#
#                                              med2011  \
# 0                                             public
# 1                                             public
# 2              Doctors' Care Family Medical Services
# 3                                             public
# 4  Health Assurance/Advanced Correctional Healthcare
#
#                                  med2012  \
# 0                                 public
# 1                                 public
# 2  Doctors' Care Family Medical Services
# 3                                 public
# 4       Advanced Correctional Healthcare
#
#                                  med2013  \
# 0                                 public
# 1                                 public
# 2  Doctors' Care Family Medical Services
# 3                                 public
# 4       Advanced Correctional Healthcare
#
#                                  med2014  \
# 0                                 public
# 1                                 public
# 2  Doctors' Care Family Medical Services
# 3                                 public
# 4       Advanced Correctional Healthcare
#
#                                    med2015  \
# 0                                   public
# 1  public/Quality Correctional Health Care
# 2    Doctors' Care Family Medical Services
# 3                                   public
# 4         Advanced Correctional Healthcare
#
#                                    med2016  \
# 0  public/Quality Correctional Health Care
# 1         Quality Correctional Health Care
# 2    Doctors' Care Family Medical Services
# 3                                   public
# 4         Advanced Correctional Healthcare
#
#                                              med2017  \
# 0                   Quality Correctional Health Care
# 1  Quality Correctional Health Care/Southern Heal...
# 2              Doctors' Care Family Medical Services
# 3                                             public
# 4                   Advanced Correctional Healthcare
#
#                                  med2018                           med2019
# 0       Quality Correctional Health Care  Quality Correctional Health Care
# 1               Southern Health Partners          Southern Health Partners
# 2  Doctors' Care Family Medical Services                               NaN
# 3                                 public                            public
# 4       Advanced Correctional Healthcare  Advanced Correctional Healthcare
#
# [5 rows x 116 columns]

# %%
jails2008 = jails[["id","statecode", "state", "state_notes", "county", "jail", "jail_notes", "d2008","su2008", "da2008", "il2008", "o2008", "ho2008", "ac2008", "adp2008", "med2008"]]
jails2009 = jails[["id","statecode", "state", "state_notes", "county", "jail", "jail_notes", "d2009","su2009", "da2009", "il2009", "o2009", "ho2009", "ac2009", "adp2009", "med2009"]]
jails2010 = jails[["id","statecode", "state", "state_notes", "county", "jail", "jail_notes", "d2010","su2010", "da2010", "il2010", "o2010", "ho2010", "ac2010", "adp2010", "med2010"]]
jails2011 = jails[["id","statecode", "state", "state_notes", "county", "jail", "jail_notes", "d2011","su2011", "da2011", "il2011", "o2011", "ho2011", "ac2011", "adp2011", "med2011"]]
jails2012 = jails[["id","statecode", "state", "state_notes", "county", "jail", "jail_notes", "d2012","su2012", "da2012", "il2012", "o2012", "ho2012", "ac2012", "adp2012", "med2012"]]
jails2013 = jails[["id","statecode", "state", "state_notes", "county", "jail", "jail_notes", "d2013","su2013", "da2013", "il2013", "o2013", "ho2013", "ac2013", "adp2013", "med2013"]]
jails2014 = jails[["id","statecode", "state", "state_notes", "county", "jail", "jail_notes", "d2014","su2014", "da2014", "il2014", "o2014", "ho2014", "ac2014", "adp2014", "med2014"]]
jails2015 = jails[["id","statecode", "state", "state_notes", "county", "jail", "jail_notes", "d2015","su2015", "da2015", "il2015", "o2015", "ho2015", "ac2015", "adp2015", "med2015"]]
jails2016 = jails[["id","statecode", "state", "state_notes", "county", "jail", "jail_notes", "d2016","su2016", "da2016", "il2016", "o2016", "ho2016", "ac2016", "adp2016", "med2016"]]
jails2017 = jails[["id","statecode", "state", "state_notes", "county", "jail", "jail_notes", "d2017","su2017", "da2017", "il2017", "o2017", "ho2017", "ac2017", "adp2017", "med2017"]]
jails2018 = jails[["id","statecode", "state", "state_notes", "county", "jail", "jail_notes", "d2018","su2018", "da2018", "il2018", "o2018", "ho2018", "ac2018", "adp2018", "med2018"]]
jails2019 = jails[["id","statecode", "state", "state_notes", "county", "jail", "jail_notes", "d2019","su2019", "da2019", "il2019", "o2019", "ho2019", "ac2019", "adp2019", "med2019"]]

# %%
stats.f_oneway(jails["d2008"].dropna(), jails["d2009"].dropna(), jails["d2010"].dropna(), jails["d2011"].dropna(), jails["d2012"].dropna(), jails["d2013"].dropna(), jails["d2014"].dropna(), jails["d2015"].dropna(), jails["d2016"].dropna(), jails["d2017"].dropna(), jails["d2018"].dropna(), jails["d2019"].dropna())
# Out:
# F_onewayResult(statistic=1.9625561273924328, pvalue=0.027959540347899874)

# %%
stats.f_oneway(jails["su2008"].dropna(), jails["su2009"].dropna(), jails["su2010"].dropna(), jails["su2011"].dropna(), jails["su2012"].dropna(), jails["su2013"].dropna(), jails["su2014"].dropna(), jails["su2015"].dropna(), jails["su2016"].dropna(), jails["su2017"].dropna(), jails["su2018"].dropna(), jails["su2019"].dropna())
# Out:
# F_onewayResult(statistic=2.4008402576715695, pvalue=0.005713528487131408)

# %%
deaths = pd.read_csv("data/all_deaths_clean")

# %%
deaths
# Out:
#          id state      county                                jail  year  \
# 0       1.0    AL     Baldwin         Baldwin County Corr. Center  2010
# 1       1.0    AL     Baldwin         Baldwin County Corr. Center  2011
# 2       1.0    AL     Baldwin         Baldwin County Corr. Center  2015
# 3       1.0    AL     Baldwin         Baldwin County Corr. Center  2015
# 4       1.0    AL     Baldwin         Baldwin County Corr. Center  2018
# ...     ...   ...         ...                                 ...   ...
# 7566  499.0    WY     Natrona     Natrona County Detention Center  2013
# 7567  499.0    WY     Natrona     Natrona County Detention Center  2015
# 7568  500.0    WY      Platte      Platte County Detention Center  2011
# 7569  501.0    WY    Sheridan    Sheridan County Detention Center  2016
# 7570  502.0    WY  Sweetwater  Sweetwater County Detention Center  2019
#
#      date_of_death full_name  last_name first_name mid_name  ...  \
# 0              NaN       NaN        NaN        NaN      NaN  ...
# 1              NaN       NaN        NaN        NaN      NaN  ...
# 2              NaN       NaN        NaN        NaN      NaN  ...
# 3              NaN       NaN        NaN        NaN      NaN  ...
# 4              NaN       NaN        NaN        NaN      NaN  ...
# ...            ...       ...        ...        ...      ...  ...
# 7566      9/6/2013       NaN          M          G      NaN  ...
# 7567     5/19/2015       NaN          W          B      NaN  ...
# 7568    11/21/2011       NaN     Willis     Vickey      NaN  ...
# 7569    12/26/2016       NaN       Hall    Richard      NaN  ...
# 7570    10/13/2019       NaN  Griffiths    Zachary      NaN  ...
#
#                                            cause_detail       dob yob   age  \
# 0                                                   NaN       NaN NaN   NaN
# 1                                                   NaN       NaN NaN   NaN
# 2                                                   NaN       NaN NaN   NaN
# 3                                                   NaN       NaN NaN   NaN
# 4                                acute bronchopneumonia       NaN NaN   NaN
# ...                                                 ...       ...  ..   ...
# 7566                               sudden cardiac death       NaN NaN  63.0
# 7567   cerebral hypoxia due to cardiopulmonary collapse       NaN NaN  47.0
# 7568                                            unknown  4/2/1960 NaN   NaN
# 7569                                                NaN       NaN NaN  45.0
# 7570  sudden cardiac death due to myocardial infarct...       NaN NaN   NaN
#
#      race  race_detail  gender custody_status what_info_from_media  \
# 0     NaN          NaN     NaN            NaN                  NaN
# 1     NaN          NaN     NaN            NaN                  NaN
# 2     NaN          NaN     NaN            NaN                  NaN
# 3     NaN          NaN     NaN            NaN                  NaN
# 4     NaN          NaN     NaN            NaN                  NaN
# ...   ...          ...     ...            ...                  ...
# 7566    W          NaN       m              U                  NaN
# 7567    W          NaN       m              C                  NaN
# 7568  NaN          NaN       f              C                  NaN
# 7569    W          NaN       m              U                  NaN
# 7570    W          NaN       m              U                  NaN
#
#      num_media_descriptors
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 7566                   NaN
# 7567                   NaN
# 7568                   NaN
# 7569                   NaN
# 7570                   NaN
#
# [7571 rows x 23 columns]

# %%
jail_deaths = pd.merge(jails,deaths, on="id")

# %%
jail_deaths
# Out:
#        id     fips statecode  state_x state_notes    county_x  \
# 0       1   1003.0        AL  Alabama         NaN     Baldwin
# 1       1   1003.0        AL  Alabama         NaN     Baldwin
# 2       1   1003.0        AL  Alabama         NaN     Baldwin
# 3       1   1003.0        AL  Alabama         NaN     Baldwin
# 4       1   1003.0        AL  Alabama         NaN     Baldwin
# ...   ...      ...       ...      ...         ...         ...
# 7515  499  56025.0        WY  Wyoming         NaN     Natrona
# 7516  499  56025.0        WY  Wyoming         NaN     Natrona
# 7517  500  56031.0        WY  Wyoming         NaN      Platte
# 7518  501  56033.0        WY  Wyoming         NaN    Sheridan
# 7519  502  56037.0        WY  Wyoming         NaN  Sweetwater
#
#                                   jail_x jail_notes  d2008  d2009  ...  \
# 0            Baldwin County Corr. Center        NaN    0.0    0.0  ...
# 1            Baldwin County Corr. Center        NaN    0.0    0.0  ...
# 2            Baldwin County Corr. Center        NaN    0.0    0.0  ...
# 3            Baldwin County Corr. Center        NaN    0.0    0.0  ...
# 4            Baldwin County Corr. Center        NaN    0.0    0.0  ...
# ...                                  ...        ...    ...    ...  ...
# 7515     Natrona County Detention Center        NaN    0.0    1.0  ...
# 7516     Natrona County Detention Center        NaN    0.0    1.0  ...
# 7517      Platte County Detention Center        NaN    0.0    0.0  ...
# 7518    Sheridan County Detention Center        NaN    0.0    0.0  ...
# 7519  Sweetwater County Detention Center        NaN    0.0    0.0  ...
#
#                                            cause_detail       dob  yob   age  \
# 0                                                   NaN       NaN  NaN   NaN
# 1                                                   NaN       NaN  NaN   NaN
# 2                                                   NaN       NaN  NaN   NaN
# 3                                                   NaN       NaN  NaN   NaN
# 4                                acute bronchopneumonia       NaN  NaN   NaN
# ...                                                 ...       ...  ...   ...
# 7515                               sudden cardiac death       NaN  NaN  63.0
# 7516   cerebral hypoxia due to cardiopulmonary collapse       NaN  NaN  47.0
# 7517                                            unknown  4/2/1960  NaN   NaN
# 7518                                                NaN       NaN  NaN  45.0
# 7519  sudden cardiac death due to myocardial infarct...       NaN  NaN   NaN
#
#       race  race_detail  gender  custody_status  what_info_from_media  \
# 0      NaN          NaN     NaN             NaN                   NaN
# 1      NaN          NaN     NaN             NaN                   NaN
# 2      NaN          NaN     NaN             NaN                   NaN
# 3      NaN          NaN     NaN             NaN                   NaN
# 4      NaN          NaN     NaN             NaN                   NaN
# ...    ...          ...     ...             ...                   ...
# 7515     W          NaN       m               U                   NaN
# 7516     W          NaN       m               C                   NaN
# 7517   NaN          NaN       f               C                   NaN
# 7518     W          NaN       m               U                   NaN
# 7519     W          NaN       m               U                   NaN
#
#       num_media_descriptors
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 7515                    NaN
# 7516                    NaN
# 7517                    NaN
# 7518                    NaN
# 7519                    NaN
#
# [7520 rows x 138 columns]

# %%
deaths[deaths["gender"] == "f"].groupby("id")["gender"].count()
# Out:
# id
# 4.0      1
# 5.0      1
# 7.0      2
# 9.0      1
# 10.0     1
#         ..
# 520.0    1
# 522.0    1
# 523.0    1
# 524.0    1
# 525.0    9
# Name: gender, Length: 304, dtype: int64

# %%
deaths[deaths["gender"] == "m"].groupby("id")["gender"].count()
# Out:
# id
# 2.0       3
# 4.0       5
# 5.0       4
# 7.0       5
# 8.0       5
#          ..
# 520.0    15
# 521.0     2
# 523.0     1
# 524.0     7
# 525.0    41
# Name: gender, Length: 476, dtype: int64

# %%
deaths.pivot_table(index='id', 
                     columns='gender', 
                     values='first_name',
                     fill_value=0, 
                     aggfunc='count')
# Out:
# gender  f   m
# id
# 2.0     0   3
# 4.0     1   5
# 5.0     1   4
# 7.0     2   3
# 8.0     0   5
# ...    ..  ..
# 521.0   0   2
# 522.0   1   0
# 523.0   1   1
# 524.0   1   7
# 525.0   9  41
#
# [490 rows x 2 columns]
